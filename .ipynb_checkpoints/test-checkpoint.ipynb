# %%
import networkit as nk
from networkit import nxadapter
import pandas as pd
import networkx as nx
# %matplotlib inline
import matplotlib.pyplot as plt

from GraphRicciCurvature.FormanRicci import FormanRicci
from GraphRicciCurvature.OllivierRicci import OllivierRicci

# %% [markdown]
# # tasks
# 1) compute and compare ORC on graph with edge weights computed by node features vs. without
# 2) expand calculation #hop nbrs
# 3) can you show that x hops is enough for global structure?
# 4) compare with resistance curvature

# %% [markdown]
# # cora ORC edge weight comparison

# %%
import os
os.getcwd()
# Out:
# '/Users/nicolexing/Documents/GitHub/GraphRicciCurvature'

# %%
cora = nx.read_gexf("/Users/nicolexing/Documents/GitHub/GraphRicciCurvature/data/cora_rf_sinkhorn_e2_20.gexf", node_type=None, relabel=False, version='1.2draft')
print(cora.number_of_edges())
print(cora.number_of_nodes())
# Out:
# 5069
# 2485

# %% [markdown]
# the above cora comes with precomputed ricci curvature

# %%
cora.edges(data=True)
# Out:
# EdgeDataView([('74700', '23069', {'ricciCurvature': -0.09055979874674813, 'original_RC': 7.781024178310503e-07, 'id': '0', 'weight': 0.16980723753665147}), ('74700', '134307', {'ricciCurvature': -0.09142913152972798, 'original_RC': -6.701576601786385e-05, 'id': '1', 'weight': 0.303447956272575}), ('684986', '684972', {'ricciCurvature': -0.08102536514260028, 'original_RC': 0.33054615059788206, 'id': '2', 'weight': 0.07311672541602887}), ('684986', '395553', {'ricciCurvature': -0.08724230597492855, 'original_RC': 0.24797210480849885, 'id': '3', 'weight': 0.16085391798926976}), ('684986', '4330', {'ricciCurvature': -0.10513598588133877, 'original_RC': -0.4375042430640179, 'id': '4', 'weight': 2.0330851725734043}), ('127940', '1114364', {'ricciCurvature': -0.16934001450457736, 'original_RC': 0.24999999931299322, 'id': '5', 'weight': 0.06479661118099896}), ('127940', '243274', {'ricciCurvature': -0.16934001450457736, 'original_RC': 0.24999999931299322, 'id': '6', 'weight': 0.06479661118099896}), ('127940', '416964', {'ricciCurvature': -0.16934001450457714, 'original_RC': 0.24999999931299322, 'id': '7', 'weight': 0.06479661118099897}), ('127940', '430329', {'ricciCurvature': -0.16546681480634562, 'original_RC': -0.24999999994415822, 'id': '8', 'weight': 0.26179972992455397}), ('686015', '27623', {'ricciCurvature': -0.08549643708584798, 'original_RC': 0.1526132363630467, 'id': '9', 'weight': 0.1827512843689697}), ('686015', '75674', {'ricciCurvature': -0.10424038016389203, 'original_RC': -0.12502605092469832, 'id': '10', 'weight': 0.11391170906463703}), ('686015', '27627', {'ricciCurvature': -0.09085870300362053, 'original_RC': -0.10006009982505937, 'id': '11', 'weight': 0.22783987809991593}), ('686015', '28254', {'ricciCurvature': -0.09317373653077143, 'original_RC': -0.00010846811232179121, 'id': '12', 'weight': 0.23208611583068492}), ('23448', '19621', {'ricciCurvature': -0.07203369908392965, 'original_RC': -0.045957923228279185, 'id': '13', 'weight': 0.30569458364769}), ('23448', '1365', {'ricciCurvature': -0.09181927109524324, 'original_RC': -0.4639832221273825, 'id': '14', 'weight': 2.915727718939352}), ('23448', '123825', {'ricciCurvature': -0.0649635761381746, 'original_RC': -0.03360763788750143, 'id': '15', 'weight': 0.24628135296019557}), ('131117', '400473', {'ricciCurvature': -0.07979284597268865, 'original_RC': 0.37263199660105384, 'id': '16', 'weight': 0.09741460590379758}), ('131117', '29492', {'ricciCurvature': -0.08309871616978093, 'original_RC': -0.12505148445472036, 'id': '17', 'weight': 0.2820783438523704}), ('131117', '152219', {'ricciCurvature': -0.0761061595214545, 'original_RC': 0.041617174618516994, 'id': '18', 'weight': 0.09926687934750046}), ('131117', '212930', {'ricciCurvature': -0.07598354226390747, 'original_RC': -0.5000000000858451, 'id': '19', 'weight': 0.17462056506304413}), ('144330', '63486', {'ricciCurvature': -0.07556590944727826, 'original_RC': -0.5416666667223733, 'id': '20', 'weight': 2.390566019970574}), ('144330', '22431', {'ricciCurvature': -0.05597757946604309, 'original_RC': -0.5416666667223733, 'id': '21', 'weight': 0.161304205043009}), ('144330', '20193', {'ricciCurvature': -0.09074320704857342, 'original_RC': -0.6231884058155046, 'id': '22', 'weight': 2.2685551209164}), ('1121867', '8079', {'ricciCurvature': -0.05948999533821908, 'original_RC': -0.3250479513993705, 'id': '32', 'weight': 1.8853207870266173}), ('1121867', '5055', {'ricciCurvature': -0.10425590156196751, 'original_RC': -0.16671128726614648, 'id': '33', 'weight': 0.30217788537541757}), ('1121867', '154982', {'ricciCurvature': -0.059208467577665624, 'original_RC': -0.28760876293646787, 'id': '34', 'weight': 1.2440518736183965}), ('1121867', '59045', {'ricciCurvature': -0.13014081428839952, 'original_RC': -0.26671415060395476, 'id': '35', 'weight': 0.35225634587510674}), ('1121867', '2654', {'ricciCurvature': -0.1003588070398651, 'original_RC': -0.3695098154193821, 'id': '36', 'weight': 1.6386401568996063}), ('1105505', '667 ...

# %%
df = pd.DataFrame.from_dict(dict(cora.nodes(data=True)), orient='index')
df.head()
# Out:
#                         class  ricciCurvature   label
# 74700   Probabilistic_Methods       -0.090994   74700
# 684986        Neural_Networks       -0.091135  684986
# 127940        Neural_Networks       -0.168372  127940
# 686015        Neural_Networks       -0.093442  686015
# 23448         Neural_Networks       -0.076272   23448

# %%
cora.edges()
# Out:
# EdgeView([('74700', '23069'), ('74700', '134307'), ('684986', '684972'), ('684986', '395553'), ('684986', '4330'), ('127940', '1114364'), ('127940', '243274'), ('127940', '416964'), ('127940', '430329'), ('686015', '27623'), ('686015', '75674'), ('686015', '27627'), ('686015', '28254'), ('23448', '19621'), ('23448', '1365'), ('23448', '123825'), ('131117', '400473'), ('131117', '29492'), ('131117', '152219'), ('131117', '212930'), ('144330', '63486'), ('144330', '22431'), ('144330', '20193'), ('1121867', '8079'), ('1121867', '5055'), ('1121867', '154982'), ('1121867', '59045'), ('1121867', '2654'), ('1105505', '66794'), ('1105505', '66782'), ('103543', '126926'), ('103543', '126927'), ('103543', '126912'), ('103543', '126920'), ('103543', '126909'), ('1104055', '2653'), ('1104055', '3243'), ('1104055', '36140'), ('1104055', '36145'), ('469504', '2696'), ('469504', '43639'), ('469504', '330208'), ('35852', '486840'), ('35852', '1113438'), ('35852', '41732'), ('35852', '1035'), ('193918', '1111240'), ('6151', '1107355'), ('6151', '887'), ('6151', '1130567'), ('6151', '6152'), ('6151', '6214'), ('6151', '6213'), ('6151', '6155'), ('6151', '4584'), ('6151', '193742'), ('6151', '1385'), ('6151', '1106547'), ('6152', '193742'), ('6152', '299195'), ('189572', '1134348'), ('189572', '16008'), ('189572', '714256'), ('189572', '189571'), ('6155', '114'), ('6155', '6214'), ('6155', '6213'), ('6155', '1126029'), ('6155', '4584'), ('189571', '521855'), ('189571', '39890'), ('189571', '714289'), ('189571', '1154232'), ('189571', '714748'), ('189571', '16008'), ('287787', '1123756'), ('287787', '634938'), ('287787', '1130847'), ('287787', '634902'), ('287787', '634975'), ('287787', '35'), ('287787', '1130856'), ('287787', '110041'), ('287787', '634904'), ('287787', '647447'), ('287787', '503883'), ('287787', '415693'), ('289780', '289781'), ('289780', '1128453'), ('289780', '289779'), ('289780', '87417'), ('289780', '35'), ('289780', '1153784'), ('289780', '801170'), ('289781', '1128453'), ('289781', '87417'), ('289781', '35'), ('289781', '1153784'), ('289781', '801170'), ('1106287', '83826'), ('1106287', '19621'), ('1106287', '1365'), ('1106287', '83847'), ('158098', '15987'), ('158098', '15984'), ('158098', '16008'), ('69392', '240321'), ('69392', '1365'), ('69392', '1132461'), ('69392', '4330'), ('1132434', '147870'), ('1132434', '240321'), ('69397', '6767'), ('69397', '6311'), ('69397', '3220'), ('65650', '1105450'), ('65650', '5038'), ('65650', '2653'), ('65650', '23738'), ('65650', '38722'), ('65650', '1118764'), ('65650', '309476'), ('65650', '11342'), ('65650', '12182'), ('65653', '3217'), ('65653', '8224'), ('65653', '1105450'), ('65653', '3235'), ('65653', '1272'), ('65653', '1112319'), ('65653', '6771'), ('100701', '1107041'), ('1102442', '1999'), ('1102442', '1997'), ('853114', '853115'), ('853114', '19621'), ('853114', '853116'), ('853114', '853155'), ('853115', '19621'), ('853115', '853116'), ('853115', '853155'), ('853116', '19621'), ('853116', '853155'), ('853118', '853155'), ('853118', '1140289'), ('1129015', '593104'), ('1129015', '594039'), ('1129015', '593942'), ('1129018', '94641'), ('1129018', '35'), ('1132505', '675847'), ('1132505', '675756'), ('1132505', '675649'), ('43698', '686532'), ('43698', '10531'), ('43698', '31353'), ('43698', '31349'), ('43698', '1129442'), ('85324', '299197'), ('85324', '628751'), ('1113438', '35061'), ('1113438', '240791'), ('1113438', '35'), ('1113438', '141324'), ('284023', '1152958'), ('284023', '1152959'), ('284023', '346292'), ('284023', '93555'), ('284023', '119761'), ('258259', '168958'), ('63931', '1117786'), ('63931', '2440'), ('63931', '136768'), ('63931', '136766'), ('63931', '13717'), ('63931', '37483'), ('63931', '6939'), ('93320', '23507'), ('93320', '10796'), ('93320', '6214'), ('990075', '95642'), ('2440', '136768'), ('2440', '136766'), ('2440', '1108551'), ('2440', '6923'), ('2440', '1117786'), ('2440', '49811'), ('2440', '151430'), ('2440', '1153254'), ('2440', '212777'), ...

# %%
def show_results(G, curvature="ricciCurvature"):

    # Print the first five results
    print("cora, first 5 edges: ")
    for n1,n2 in list(G.edges())[:5]:
        print("Ricci curvature of edge (%s,%s) is %f" % (n1 ,n2, G[n1][n2][curvature]))

    # Plot the histogram of Ricci curvatures
    plt.subplot(2, 1, 1)
    ricci_curvtures = nx.get_edge_attributes(G, curvature).values()
    plt.hist(ricci_curvtures,bins=20)
    plt.xlabel('Ricci curvature')
    plt.title("Histogram of Ricci Curvatures (cora)")

    # Plot the histogram of edge weights
    plt.subplot(2, 1, 2)
    weights = nx.get_edge_attributes(G, "weight").values()
    plt.hist(weights,bins=20)
    plt.xlabel('Edge weight')
    plt.title("Histogram of Edge weights (cora)")

    plt.tight_layout()

# %% [markdown]
# view the orc and frc for edges computed by default weight in graph

# %%
# compute the Ollivier-Ricci curvature of the given graph G
orc = OllivierRicci(cora, alpha=0.5, verbose="INFO")
orc.compute_ricci_curvature()
cora_orc = orc.G.copy()  # save an intermediate result
show_results(cora_orc)
# Out:
# cora, first 5 edges:
# Ricci curvature of edge (74700,23069) is -0.082299
# Ricci curvature of edge (74700,134307) is -0.053479
# Ricci curvature of edge (684986,684972) is 0.209002
# Ricci curvature of edge (684986,395553) is -0.009250
# Ricci curvature of edge (684986,4330) is -0.105087

# %%
# forman ricci
frc = FormanRicci(cora, verbose="TRACE")
frc.compute_ricci_curvature()
cora_frc = frc.G.copy()
show_results(cora_frc, curvature='formanCurvature')
# Out:
# cora, first 5 edges:
# Ricci curvature of edge (74700,23069) is -1.649498
# Ricci curvature of edge (74700,134307) is -5.232272
# Ricci curvature of edge (684986,684972) is 1.082457
# Ricci curvature of edge (684986,395553) is -0.222828
# Ricci curvature of edge (684986,4330) is -47.510357

# %% [markdown]
# view the orc and frc for edge weight computed by node similarity

# %%
for n1,n2 in list(cora.edges())[:5]:
    print(cora.get_edge_data(n1,n2))
# Out:
# {'ricciCurvature': -0.09055979874674813, 'original_RC': 7.781024178310503e-07, 'id': '0', 'weight': 0.16980723753665147}
# {'ricciCurvature': -0.09142913152972798, 'original_RC': -6.701576601786385e-05, 'id': '1', 'weight': 0.303447956272575}
# {'ricciCurvature': -0.08102536514260028, 'original_RC': 0.33054615059788206, 'id': '2', 'weight': 0.07311672541602887}
# {'ricciCurvature': -0.08724230597492855, 'original_RC': 0.24797210480849885, 'id': '3', 'weight': 0.16085391798926976}
# {'ricciCurvature': -0.10513598588133877, 'original_RC': -0.4375042430640179, 'id': '4', 'weight': 2.0330851725734043}
